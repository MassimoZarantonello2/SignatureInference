# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

sys.path.append('../')
from utils.ResultsEvaluation import ResultsEvaluation
from utils.graph_plot import *

# %% [markdown]
# ### Accuracy graphs

# %%
for t,tre in zip(thresholds,tres):
    plot_per_run_metric(tre, attr_name='per_run_balanced_accuracy', metric_name=t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for t,tre in zip(thresholds,tres):
#       2     plot_per_run_metric(tre, attr_name='per_run_balanced_accuracy', metric_name=t)
#
# NameError: name 'thresholds' is not defined
