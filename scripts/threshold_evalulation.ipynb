# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

sys.path.append('../')
from utils.ResultsEvaluation import ResultsEvaluation
from utils.graph_plot import *

# %%
thresholds = np.arange(1,8)
tres = []

for t in thresholds:
    tres.append(ResultsEvaluation(f'./threshold/default_{t}_evaluations'))

# %% [markdown]
# ### Accuracy graphs

# %%
for t,tre in zip(thresholds,tres):
    plot_per_run_metric(tre, attr_name='per_run_balanced_accuracy', metric_name=t)
